# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Datasets

# %%
# get data sets
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('../Data_sets/MNIST_data', one_hot=True)
# Out:
# Extracting ../Data_sets/MNIST_data\train-images-idx3-ubyte.gz
# Extracting ../Data_sets/MNIST_data\train-labels-idx1-ubyte.gz
# Extracting ../Data_sets/MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting ../Data_sets/MNIST_data\t10k-labels-idx1-ubyte.gz

# %% [markdown]
# # Build weight & bias initializer by name

# %%
def get_initial_weights_bias_by_name(name):
    mean = 0.0
    stddev = 0.1
    dtype = tf.float32
    if name == 'normal':
        w_init = tf.random_normal_initializer(mean=mean, stddev=stddev, dtype=dtype)
    elif name == 'truncated':
        w_init = tf.truncated_normal_initializer(mean=mean, stddev=stddev, dtype=dtype)
    elif name == 'xavier':
        #w_init = tf.contrib.layers.variance_scaling_initializer(factor=1.0, mode='FAN_AVG', uniform=True, dtype=dtype)
        w_init = tf.contrib.layers.xavier_initializer(uniform=True, dtype=dtype)
    elif name == 'he':
        w_init = tf.contrib.layers.variance_scaling_initializer(factor=2.0, mode='FAN_IN', uniform=False, dtype=dtype)
    
    b_init = tf.zeros_initializer(dtype=dtype)
    return w_init, b_init

# %% [markdown]
# # Model builder functions

# %%
def model_inputs(n_input, n_output):
    with tf.name_scope('placeholders'):
        inputs = tf.placeholder(tf.float32, shape=[None, n_input], name='inputs')
        labels = tf.placeholder(tf.float32, shape=[None, n_output], name='labels')
    
    return inputs, labels

# %%
def mlp_with_batch_norm(inputs, n_hidden, n_output, param_init_type, is_training=True):
    with tf.variable_scope('with_batch_norm'):
        # get weights & bias
        w_init, b_init = get_initial_weights_bias_by_name(param_init_type)
        h1 = tf.layers.dense(inputs=inputs, units=n_hidden, activation=None, kernel_initializer=w_init, bias_initializer=b_init)
        h1 = tf.layers.batch_normalization(inputs=h1, training=is_training)
        h1 = tf.nn.relu(h1)

        h2 = tf.layers.dense(inputs=h1, units=n_hidden, activation=None, kernel_initializer=w_init, bias_initializer=b_init)
        h2 = tf.layers.batch_normalization(inputs=h2, training=is_training)
        h2 = tf.nn.relu(h2)

        logits = tf.layers.dense(inputs=h2, units=n_output, activation=None, kernel_initializer=w_init, bias_initializer=b_init)
    
    return logits

# %%
def mlp_without_batch_norm(inputs, n_hidden, n_output, param_init_type, is_training=True):
    with tf.variable_scope('without_batch_norm'):
        # get weights & bias
        w_init, b_init = get_initial_weights_bias_by_name(param_init_type)
        h1 = tf.layers.dense(inputs=inputs, units=n_hidden, activation=tf.nn.relu, kernel_initializer=w_init, bias_initializer=b_init)
        h2 = tf.layers.dense(inputs=h1, units=n_hidden, activation=tf.nn.relu, kernel_initializer=w_init, bias_initializer=b_init)
        logits = tf.layers.dense(inputs=h2, units=n_output, activation=None, kernel_initializer=w_init, bias_initializer=b_init)
    
    return logits

# %%
def model_loss_acc(inputs, labels, n_hidden, n_output, param_init_type='normal', use_batch_norm=False):
    if use_batch_norm:
        logits = mlp_with_batch_norm(inputs, n_hidden, n_output, param_init_type, is_training=True)
    else:
        logits = mlp_without_batch_norm(inputs, n_hidden, n_output, param_init_type, is_training=True)
    
    # create name string for tensorboard
    result_dict_key = param_init_type + '.' + str(use_batch_norm).lower()
    with tf.name_scope('logits'):        
        tf.summary.histogram(name=result_dict_key + '.logits', values=logits)
    
    with tf.name_scope('cost'):
        # compute loss
        loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=labels), name='loss' )
        tf.summary.scalar(name=result_dict_key + '.loss', tensor=loss)
    
    with tf.name_scope('predictions'):
        # compute accuracy
        correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1))
        acc = tf.reduce_mean( tf.cast(correct_prediction, tf.float32), name='accuracy' )
        tf.summary.scalar(name=result_dict_key + '.accuracy', tensor=acc)
    
    return loss, acc

# %%
def model_opt(loss, learning_rate, use_batch_norm=False):
    with tf.name_scope('train'):
        if use_batch_norm:
            # take care of batch norm
            with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
                opt = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)
        else:
            opt = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)
    
    return opt

# %%
class TestNet:
    def __init__(self, n_input, n_output, n_hidden, learning_rate, param_init_type, use_batch_norm):
        tf.reset_default_graph()
        
        self.inputs, self.labels = model_inputs(n_input, n_output)
        self.loss, self.acc = model_loss_acc(self.inputs, self.labels, n_hidden, n_output, param_init_type, use_batch_norm)
        self.optimizer = model_opt(self.loss, learning_rate, use_batch_norm)
        self.merged_summary = tf.summary.merge_all()

# %%
def train(net, epochs, batch_size, print_every, train_writer):
    losses = []
    accrucacies = []
    steps = 0
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        
        for e in range(epochs):
            for ii in range(mnist.train.num_examples//batch_size):
                steps += 1
                
                # get input data
                batch_x, batch_y = mnist.train.next_batch(batch_size)
                
                # run optimizer
                _, train_loss, train_acc, summary = sess.run([net.optimizer, net.loss, net.acc, net.merged_summary], 
                                                             feed_dict={net.inputs: batch_x, net.labels: batch_y})
                
                train_writer.add_summary(summary, steps)
                
                # print
                if steps % print_every == 0:
                    print("Epoch {}/{}...".format(e+1, epochs), "Loss: {:.4f}...".format(train_loss), "Acc: {:.4f}...".format(train_acc))
                    losses.append(train_loss)
                    accrucacies.append(train_acc)
    
    return losses, accrucacies

# %% [markdown]
# # Training

# %%
# network params
n_input = 784
n_hidden = 256
n_classes = 10

# train params
training_epochs = 15
batch_size = 100
display_step = 100
learning_rate = 0.001

# %%
# first create dictionary to hold training result
results = {
    'normal.false': { 'loss': [], 'acc': [] },
    'normal.true': { 'loss': [], 'acc': [] },
    'truncated.false': { 'loss': [], 'acc': [] },
    'truncated.true': { 'loss': [], 'acc': [] },
    'xavier.false': { 'loss': [], 'acc': [] },
    'xavier.true': { 'loss': [], 'acc': [] },
    'he.false': { 'loss': [], 'acc': [] },
    'he.true': { 'loss': [], 'acc': [] } }

# %%
# train on every test settings
param_init_list = ['normal', 'truncated', 'xavier', 'he']
use_batch_norm_list = [True, False]

train_writer = tf.summary.FileWriter('./logs/1')

for init_name in param_init_list:
    for use_BN in use_batch_norm_list:
        # create dictionary key
        result_dict_key = init_name + '.' + str(use_BN).lower()
        print('[Running]: {}!!!'.format(result_dict_key))
        
        # create network
        net = TestNet(n_input, n_classes, n_hidden, learning_rate, init_name, use_BN)
        
        # save trainint result
        results[result_dict_key]['loss'], results[result_dict_key]['acc'] = train(net, training_epochs, batch_size, display_step, train_writer)
# Out:
# [Running]: normal.true!!!
# Epoch 1/15... Loss: 0.3312... Acc: 0.9300...
# Epoch 1/15... Loss: 0.2035... Acc: 0.9200...
# Epoch 1/15... Loss: 0.1601... Acc: 0.9500...
# Epoch 1/15... Loss: 0.1746... Acc: 0.9200...
# Epoch 1/15... Loss: 0.0929... Acc: 0.9700...
# Epoch 2/15... Loss: 0.0621... Acc: 0.9900...
# Epoch 2/15... Loss: 0.0461... Acc: 1.0000...
# Epoch 2/15... Loss: 0.0650... Acc: 0.9800...
# Epoch 2/15... Loss: 0.1086... Acc: 0.9700...
# Epoch 2/15... Loss: 0.1049... Acc: 0.9700...
# Epoch 2/15... Loss: 0.0462... Acc: 0.9900...
# Epoch 3/15... Loss: 0.0520... Acc: 0.9700...
# Epoch 3/15... Loss: 0.0620... Acc: 0.9800...
# Epoch 3/15... Loss: 0.1263... Acc: 0.9600...
# Epoch 3/15... Loss: 0.0135... Acc: 1.0000...
# Epoch 3/15... Loss: 0.0451... Acc: 0.9900...
# Epoch 4/15... Loss: 0.0159... Acc: 1.0000...
# Epoch 4/15... Loss: 0.0199... Acc: 0.9900...
# Epoch 4/15... Loss: 0.0095... Acc: 1.0000...
# Epoch 4/15... Loss: 0.0146... Acc: 1.0000...
# Epoch 4/15... Loss: 0.0708... Acc: 0.9800...
# Epoch 4/15... Loss: 0.0460... Acc: 0.9900...
# Epoch 5/15... Loss: 0.0343... Acc: 0.9900...
# Epoch 5/15... Loss: 0.0170... Acc: 0.9900...
# Epoch 5/15... Loss: 0.0056... Acc: 1.0000...
# Epoch 5/15... Loss: 0.0297... Acc: 0.9900...
# Epoch 5/15... Loss: 0.0085... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0127... Acc: 0.9900...
# Epoch 6/15... Loss: 0.0105... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0863... Acc: 0.9700...
# Epoch 6/15... Loss: 0.0104... Acc: 0.9900...
# Epoch 6/15... Loss: 0.0103... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0147... Acc: 0.9900...
# Epoch 7/15... Loss: 0.0296... Acc: 0.9900...
# Epoch 7/15... Loss: 0.0202... Acc: 0.9900...
# Epoch 7/15... Loss: 0.0043... Acc: 1.0000...
# Epoch 7/15... Loss: 0.0096... Acc: 1.0000...
# Epoch 7/15... Loss: 0.0264... Acc: 0.9900...
# Epoch 8/15... Loss: 0.0079... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0046... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0121... Acc: 0.9900...
# Epoch 8/15... Loss: 0.0185... Acc: 0.9900...
# Epoch 8/15... Loss: 0.0034... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0215... Acc: 0.9900...
# Epoch 9/15... Loss: 0.0199... Acc: 0.9900...
# Epoch 9/15... Loss: 0.0030... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0167... Acc: 0.9900...
# Epoch 9/15... Loss: 0.0037... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0427... Acc: 0.9800...
# Epoch 10/15... Loss: 0.0029... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0059... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0056... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0067... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0201... Acc: 0.9900...
# Epoch 10/15... Loss: 0.0102... Acc: 0.9900...
# Epoch 11/15... Loss: 0.0203... Acc: 0.9900...
# Epoch 11/15... Loss: 0.0068... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0023... Acc: 1.0000...
# Epoch 11/15... Loss: 0.1143... Acc: 0.9800...
# Epoch 11/15... Loss: 0.0008... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0020... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0027... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0400... Acc: 0.9900...
# Epoch 12/15... Loss: 0.0109... Acc: 0.9900...
# Epoch 12/15... Loss: 0.0023... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0015... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0046... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0029... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0232... Acc: 0.9900...
# Epoch 13/15... Loss: 0.0008... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0032... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0019... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0080... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0063... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0062... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0021... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0021... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0023... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0021... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0118... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0021... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0013... Acc: 1.0000...
# [Running]: normal.false!!!
# Epoch 1/15... Loss: 0.3258... Acc: 0.9000...
# Epoch 1/15... Loss: 0.1958... Acc: 0.9400...
# Epoch 1/15... Loss: 0.1554... Acc: 0.9600...
# Epoch 1/15... Loss: 0.0829... Acc: 0.9700...
# Epoch 1/15... Loss: 0.1082... Acc: 0.9800...
# Epoch 2/15... Loss: 0.1298... Acc: 0.9600...
# Epoch 2/15... Loss: 0.1151... Acc: 0.9600...
# Epoch 2/15... Loss: 0.0970... Acc: 0.9700...
# Epoch 2/15... Loss: 0.1874... Acc: 0.9400...
# Epoch 2/15... Loss: 0.0935... Acc: 0.9600...
# Epoch 2/15... Loss: 0.0979... Acc: 0.9700...
# Epoch 3/15... Loss: 0.0396... Acc: 0.9900...
# Epoch 3/15... Loss: 0.0297... Acc: 0.9900...
# Epoch 3/15... Loss: 0.0437... Acc: 0.9900...
# Epoch 3/15... Loss: 0.0789... Acc: 0.9800...
# Epoch 3/15... Loss: 0.0929... Acc: 0.9600...
# Epoch 4/15... Loss: 0.0152... Acc: 0.9900...
# Epoch 4/15... Loss: 0.0537... Acc: 0.9800...
# Epoch 4/15... Loss: 0.0705... Acc: 0.9700...
# Epoch 4/15... Loss: 0.0477... Acc: 0.9800...
# Epoch 4/15... Loss: 0.0083... Acc: 1.0000...
# Epoch 4/15... Loss: 0.0863... Acc: 0.9600...
# Epoch 5/15... Loss: 0.0429... Acc: 0.9900...
# Epoch 5/15... Loss: 0.0274... Acc: 0.9900...
# Epoch 5/15... Loss: 0.0259... Acc: 0.9900...
# Epoch 5/15... Loss: 0.0486... Acc: 0.9800...
# Epoch 5/15... Loss: 0.0099... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0051... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0066... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0365... Acc: 0.9800...
# Epoch 6/15... Loss: 0.0357... Acc: 0.9800...
# Epoch 6/15... Loss: 0.0024... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0435... Acc: 0.9900...
# Epoch 7/15... Loss: 0.0136... Acc: 1.0000...
# Epoch 7/15... Loss: 0.0225... Acc: 0.9900...
# Epoch 7/15... Loss: 0.0151... Acc: 0.9900...
# Epoch 7/15... Loss: 0.0211... Acc: 0.9900...
# Epoch 7/15... Loss: 0.0165... Acc: 0.9900...
# Epoch 8/15... Loss: 0.0077... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0013... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0049... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0032... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0054... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0007... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0112... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0024... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0191... Acc: 0.9900...
# Epoch 9/15... Loss: 0.0100... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0368... Acc: 0.9800...
# Epoch 10/15... Loss: 0.0004... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0215... Acc: 0.9900...
# Epoch 10/15... Loss: 0.0025... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0059... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0069... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0023... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0198... Acc: 0.9900...
# Epoch 11/15... Loss: 0.0007... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0018... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0042... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0387... Acc: 0.9800...
# Epoch 12/15... Loss: 0.0002... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0023... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0057... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0026... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0009... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0560... Acc: 0.9700...
# Epoch 13/15... Loss: 0.0069... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0053... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0113... Acc: 0.9900...
# Epoch 13/15... Loss: 0.0599... Acc: 0.9700...
# Epoch 13/15... Loss: 0.0089... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0019... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0341... Acc: 0.9800...
# Epoch 14/15... Loss: 0.0022... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0034... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0051... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0023... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0002... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0016... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0125... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0026... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0012... Acc: 1.0000...
# [Running]: truncated.true!!!
# Epoch 1/15... Loss: 0.3353... Acc: 0.9000...
# Epoch 1/15... Loss: 0.1210... Acc: 0.9800...
# Epoch 1/15... Loss: 0.1861... Acc: 0.9300...
# Epoch 1/15... Loss: 0.1407... Acc: 0.9400...
# Epoch 1/15... Loss: 0.0993... Acc: 0.9700...
# Epoch 2/15... Loss: 0.0867... Acc: 0.9900...
# Epoch 2/15... Loss: 0.1120... Acc: 0.9800...
# Epoch 2/15... Loss: 0.0348... Acc: 0.9900...
# Epoch 2/15... Loss: 0.0888... Acc: 0.9900...
# Epoch 2/15... Loss: 0.0681... Acc: 0.9900...
# Epoch 2/15... Loss: 0.0735... Acc: 0.9800...
# Epoch 3/15... Loss: 0.0223... Acc: 1.0000...
# Epoch 3/15... Loss: 0.0339... Acc: 0.9900...
# Epoch 3/15... Loss: 0.0208... Acc: 1.0000...
# Epoch 3/15... Loss: 0.0432... Acc: 0.9800...
# Epoch 3/15... Loss: 0.0657... Acc: 0.9700...
# Epoch 4/15... Loss: 0.0077... Acc: 1.0000...
# Epoch 4/15... Loss: 0.0121... Acc: 1.0000...
# Epoch 4/15... Loss: 0.0697... Acc: 0.9700...
# Epoch 4/15... Loss: 0.0125... Acc: 1.0000...
# Epoch 4/15... Loss: 0.0361... Acc: 0.9900...
# Epoch 4/15... Loss: 0.0108... Acc: 1.0000...
# Epoch 5/15... Loss: 0.0225... Acc: 1.0000...
# Epoch 5/15... Loss: 0.0065... Acc: 1.0000...
# Epoch 5/15... Loss: 0.0161... Acc: 1.0000...
# Epoch 5/15... Loss: 0.0081... Acc: 1.0000...
# Epoch 5/15... Loss: 0.0049... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0033... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0417... Acc: 0.9900...
# Epoch 6/15... Loss: 0.0197... Acc: 0.9900...
# Epoch 6/15... Loss: 0.0935... Acc: 0.9800...
# Epoch 6/15... Loss: 0.0045... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0190... Acc: 0.9900...
# Epoch 7/15... Loss: 0.0037... Acc: 1.0000...
# Epoch 7/15... Loss: 0.0374... Acc: 0.9800...
# Epoch 7/15... Loss: 0.0030... Acc: 1.0000...
# Epoch 7/15... Loss: 0.0656... Acc: 0.9900...
# Epoch 7/15... Loss: 0.0139... Acc: 0.9900...
# Epoch 8/15... Loss: 0.0307... Acc: 0.9800...
# Epoch 8/15... Loss: 0.0021... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0038... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0047... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0064... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0142... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0131... Acc: 0.9900...
# Epoch 9/15... Loss: 0.0084... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0062... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0327... Acc: 0.9800...
# Epoch 9/15... Loss: 0.0053... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0004... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0008... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0066... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0077... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0041... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0120... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0029... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0032... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0037... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0717... Acc: 0.9800...
# Epoch 11/15... Loss: 0.0019... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0020... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0131... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0315... Acc: 0.9900...
# Epoch 12/15... Loss: 0.0151... Acc: 0.9900...
# Epoch 12/15... Loss: 0.0094... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0128... Acc: 0.9900...
# Epoch 13/15... Loss: 0.0030... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0019... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0018... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0070... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0044... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0035... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0212... Acc: 0.9900...
# Epoch 14/15... Loss: 0.0005... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0042... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0033... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0090... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0018... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0007... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0384... Acc: 0.9800...
# Epoch 15/15... Loss: 0.0024... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0016... Acc: 1.0000...
# [Running]: truncated.false!!!
# Epoch 1/15... Loss: 0.3324... Acc: 0.9300...
# Epoch 1/15... Loss: 0.2594... Acc: 0.9200...
# Epoch 1/15... Loss: 0.1271... Acc: 0.9600...
# Epoch 1/15... Loss: 0.1226... Acc: 0.9700...
# Epoch 1/15... Loss: 0.1200... Acc: 0.9500...
# Epoch 2/15... Loss: 0.0598... Acc: 0.9900...
# Epoch 2/15... Loss: 0.1714... Acc: 0.9600...
# Epoch 2/15... Loss: 0.0530... Acc: 0.9800...
# Epoch 2/15... Loss: 0.1535... Acc: 0.9600...
# Epoch 2/15... Loss: 0.0455... Acc: 0.9800...
# Epoch 2/15... Loss: 0.0897... Acc: 0.9600...
# Epoch 3/15... Loss: 0.0986... Acc: 0.9800...
# Epoch 3/15... Loss: 0.0814... Acc: 0.9700...
# Epoch 3/15... Loss: 0.0176... Acc: 1.0000...
# Epoch 3/15... Loss: 0.0749... Acc: 0.9600...
# Epoch 3/15... Loss: 0.0745... Acc: 0.9800...
# Epoch 4/15... Loss: 0.1101... Acc: 0.9800...
# Epoch 4/15... Loss: 0.0051... Acc: 1.0000...
# Epoch 4/15... Loss: 0.0255... Acc: 0.9900...
# Epoch 4/15... Loss: 0.0177... Acc: 1.0000...
# Epoch 4/15... Loss: 0.0372... Acc: 0.9900...
# Epoch 4/15... Loss: 0.0601... Acc: 0.9700...
# Epoch 5/15... Loss: 0.0278... Acc: 0.9900...
# Epoch 5/15... Loss: 0.0508... Acc: 0.9800...
# Epoch 5/15... Loss: 0.0174... Acc: 0.9900...
# Epoch 5/15... Loss: 0.0496... Acc: 0.9900...
# Epoch 5/15... Loss: 0.0329... Acc: 0.9800...
# Epoch 6/15... Loss: 0.0015... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0073... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0330... Acc: 0.9900...
# Epoch 6/15... Loss: 0.0419... Acc: 0.9900...
# Epoch 6/15... Loss: 0.0219... Acc: 0.9900...
# Epoch 6/15... Loss: 0.0212... Acc: 0.9900...
# Epoch 7/15... Loss: 0.0181... Acc: 0.9900...
# Epoch 7/15... Loss: 0.0120... Acc: 1.0000...
# Epoch 7/15... Loss: 0.0086... Acc: 1.0000...
# Epoch 7/15... Loss: 0.0278... Acc: 0.9900...
# Epoch 7/15... Loss: 0.0138... Acc: 0.9900...
# Epoch 8/15... Loss: 0.0257... Acc: 0.9900...
# Epoch 8/15... Loss: 0.0124... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0129... Acc: 0.9900...
# Epoch 8/15... Loss: 0.0061... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0270... Acc: 0.9800...
# Epoch 8/15... Loss: 0.0398... Acc: 0.9800...
# Epoch 9/15... Loss: 0.0012... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0147... Acc: 0.9900...
# Epoch 9/15... Loss: 0.0055... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0594... Acc: 0.9800...
# Epoch 9/15... Loss: 0.0024... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0151... Acc: 0.9900...
# Epoch 10/15... Loss: 0.0031... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0023... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0027... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0009... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0040... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0035... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0055... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0039... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0218... Acc: 0.9900...
# Epoch 11/15... Loss: 0.0421... Acc: 0.9900...
# Epoch 12/15... Loss: 0.0004... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0332... Acc: 0.9800...
# Epoch 12/15... Loss: 0.0006... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0018... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0114... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0008... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0059... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0102... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0025... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0424... Acc: 0.9900...
# Epoch 13/15... Loss: 0.0197... Acc: 0.9900...
# Epoch 14/15... Loss: 0.0090... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0028... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0083... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0019... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0005... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0007... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0029... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0517... Acc: 0.9800...
# Epoch 15/15... Loss: 0.0246... Acc: 0.9800...
# Epoch 15/15... Loss: 0.0020... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0064... Acc: 1.0000...
# [Running]: xavier.true!!!
# Epoch 1/15... Loss: 0.2111... Acc: 0.9600...
# Epoch 1/15... Loss: 0.1126... Acc: 0.9400...
# Epoch 1/15... Loss: 0.2186... Acc: 0.9400...
# Epoch 1/15... Loss: 0.1162... Acc: 0.9400...
# Epoch 1/15... Loss: 0.0827... Acc: 0.9600...
# Epoch 2/15... Loss: 0.0536... Acc: 0.9700...
# Epoch 2/15... Loss: 0.0709... Acc: 0.9900...
# Epoch 2/15... Loss: 0.0716... Acc: 0.9900...
# Epoch 2/15... Loss: 0.0419... Acc: 0.9900...
# Epoch 2/15... Loss: 0.0423... Acc: 0.9800...
# Epoch 2/15... Loss: 0.0935... Acc: 0.9700...
# Epoch 3/15... Loss: 0.0313... Acc: 0.9900...
# Epoch 3/15... Loss: 0.0459... Acc: 0.9900...
# Epoch 3/15... Loss: 0.0122... Acc: 1.0000...
# Epoch 3/15... Loss: 0.0225... Acc: 1.0000...
# Epoch 3/15... Loss: 0.0700... Acc: 0.9800...
# Epoch 4/15... Loss: 0.0169... Acc: 1.0000...
# Epoch 4/15... Loss: 0.0102... Acc: 1.0000...
# Epoch 4/15... Loss: 0.0205... Acc: 1.0000...
# Epoch 4/15... Loss: 0.0084... Acc: 1.0000...
# Epoch 4/15... Loss: 0.0099... Acc: 1.0000...
# Epoch 4/15... Loss: 0.0334... Acc: 0.9900...
# Epoch 5/15... Loss: 0.0080... Acc: 1.0000...
# Epoch 5/15... Loss: 0.0129... Acc: 1.0000...
# Epoch 5/15... Loss: 0.0813... Acc: 0.9800...
# Epoch 5/15... Loss: 0.0082... Acc: 1.0000...
# Epoch 5/15... Loss: 0.0657... Acc: 0.9800...
# Epoch 6/15... Loss: 0.0476... Acc: 0.9800...
# Epoch 6/15... Loss: 0.0204... Acc: 0.9900...
# Epoch 6/15... Loss: 0.0067... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0329... Acc: 0.9800...
# Epoch 6/15... Loss: 0.0127... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0633... Acc: 0.9900...
# Epoch 7/15... Loss: 0.0097... Acc: 1.0000...
# Epoch 7/15... Loss: 0.0226... Acc: 0.9900...
# Epoch 7/15... Loss: 0.0309... Acc: 0.9900...
# Epoch 7/15... Loss: 0.0115... Acc: 1.0000...
# Epoch 7/15... Loss: 0.0462... Acc: 0.9900...
# Epoch 8/15... Loss: 0.0117... Acc: 0.9900...
# Epoch 8/15... Loss: 0.0224... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0014... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0166... Acc: 0.9900...
# Epoch 8/15... Loss: 0.0223... Acc: 0.9900...
# Epoch 8/15... Loss: 0.0050... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0196... Acc: 0.9900...
# Epoch 9/15... Loss: 0.0523... Acc: 0.9800...
# Epoch 9/15... Loss: 0.0020... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0066... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0012... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0009... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0019... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0117... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0116... Acc: 0.9900...
# Epoch 10/15... Loss: 0.0916... Acc: 0.9800...
# Epoch 10/15... Loss: 0.0014... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0010... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0243... Acc: 0.9900...
# Epoch 11/15... Loss: 0.0525... Acc: 0.9900...
# Epoch 11/15... Loss: 0.0194... Acc: 0.9900...
# Epoch 11/15... Loss: 0.0019... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0332... Acc: 0.9900...
# Epoch 12/15... Loss: 0.0004... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0061... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0008... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0017... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0319... Acc: 0.9900...
# Epoch 13/15... Loss: 0.0014... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0187... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0093... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0020... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0009... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0117... Acc: 0.9900...
# Epoch 14/15... Loss: 0.0005... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0156... Acc: 0.9900...
# Epoch 14/15... Loss: 0.0028... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0400... Acc: 0.9900...
# Epoch 14/15... Loss: 0.0048... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0615... Acc: 0.9900...
# Epoch 15/15... Loss: 0.0121... Acc: 0.9900...
# Epoch 15/15... Loss: 0.0132... Acc: 0.9900...
# Epoch 15/15... Loss: 0.0013... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0301... Acc: 0.9900...
# [Running]: xavier.false!!!
# Epoch 1/15... Loss: 0.2477... Acc: 0.9400...
# Epoch 1/15... Loss: 0.2096... Acc: 0.9300...
# Epoch 1/15... Loss: 0.0563... Acc: 0.9900...
# Epoch 1/15... Loss: 0.1888... Acc: 0.9300...
# Epoch 1/15... Loss: 0.1742... Acc: 0.9400...
# Epoch 2/15... Loss: 0.1139... Acc: 0.9700...
# Epoch 2/15... Loss: 0.1625... Acc: 0.9500...
# Epoch 2/15... Loss: 0.0739... Acc: 0.9600...
# Epoch 2/15... Loss: 0.1446... Acc: 0.9700...
# Epoch 2/15... Loss: 0.0715... Acc: 0.9800...
# Epoch 2/15... Loss: 0.0730... Acc: 0.9800...
# Epoch 3/15... Loss: 0.0426... Acc: 0.9800...
# Epoch 3/15... Loss: 0.0546... Acc: 0.9800...
# Epoch 3/15... Loss: 0.0648... Acc: 0.9700...
# Epoch 3/15... Loss: 0.0111... Acc: 1.0000...
# Epoch 3/15... Loss: 0.0379... Acc: 0.9900...
# Epoch 4/15... Loss: 0.0569... Acc: 0.9700...
# Epoch 4/15... Loss: 0.0364... Acc: 0.9900...
# Epoch 4/15... Loss: 0.0813... Acc: 0.9700...
# Epoch 4/15... Loss: 0.0787... Acc: 0.9600...
# Epoch 4/15... Loss: 0.0427... Acc: 0.9800...
# Epoch 4/15... Loss: 0.0438... Acc: 0.9900...
# Epoch 5/15... Loss: 0.0639... Acc: 0.9700...
# Epoch 5/15... Loss: 0.0242... Acc: 0.9900...
# Epoch 5/15... Loss: 0.0661... Acc: 0.9900...
# Epoch 5/15... Loss: 0.0735... Acc: 0.9800...
# Epoch 5/15... Loss: 0.0372... Acc: 0.9900...
# Epoch 6/15... Loss: 0.0020... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0192... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0280... Acc: 0.9900...
# Epoch 6/15... Loss: 0.0414... Acc: 0.9900...
# Epoch 6/15... Loss: 0.0119... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0121... Acc: 1.0000...
# Epoch 7/15... Loss: 0.0157... Acc: 0.9900...
# Epoch 7/15... Loss: 0.0631... Acc: 0.9900...
# Epoch 7/15... Loss: 0.0369... Acc: 0.9800...
# Epoch 7/15... Loss: 0.0111... Acc: 1.0000...
# Epoch 7/15... Loss: 0.0449... Acc: 0.9700...
# Epoch 8/15... Loss: 0.0047... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0074... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0066... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0062... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0477... Acc: 0.9900...
# Epoch 8/15... Loss: 0.0352... Acc: 0.9900...
# Epoch 9/15... Loss: 0.0039... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0012... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0129... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0105... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0084... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0052... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0030... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0147... Acc: 0.9900...
# Epoch 10/15... Loss: 0.0133... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0016... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0045... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0050... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0040... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0003... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0041... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0019... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0012... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0071... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0007... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0009... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0006... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0315... Acc: 0.9800...
# Epoch 13/15... Loss: 0.0453... Acc: 0.9900...
# Epoch 13/15... Loss: 0.0328... Acc: 0.9800...
# Epoch 13/15... Loss: 0.0004... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0048... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0048... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0013... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0013... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0134... Acc: 0.9900...
# Epoch 14/15... Loss: 0.0208... Acc: 0.9900...
# Epoch 14/15... Loss: 0.0039... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0116... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0051... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0001... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0008... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0007... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0067... Acc: 1.0000...
# [Running]: he.true!!!
# Epoch 1/15... Loss: 0.2823... Acc: 0.9100...
# Epoch 1/15... Loss: 0.1211... Acc: 0.9800...
# Epoch 1/15... Loss: 0.1228... Acc: 0.9500...
# Epoch 1/15... Loss: 0.1955... Acc: 0.9300...
# Epoch 1/15... Loss: 0.1104... Acc: 0.9600...
# Epoch 2/15... Loss: 0.1256... Acc: 0.9600...
# Epoch 2/15... Loss: 0.0286... Acc: 0.9900...
# Epoch 2/15... Loss: 0.0694... Acc: 0.9800...
# Epoch 2/15... Loss: 0.0407... Acc: 0.9900...
# Epoch 2/15... Loss: 0.0674... Acc: 0.9800...
# Epoch 2/15... Loss: 0.0329... Acc: 1.0000...
# Epoch 3/15... Loss: 0.0496... Acc: 0.9900...
# Epoch 3/15... Loss: 0.0758... Acc: 0.9600...
# Epoch 3/15... Loss: 0.0141... Acc: 1.0000...
# Epoch 3/15... Loss: 0.1129... Acc: 0.9600...
# Epoch 3/15... Loss: 0.0105... Acc: 1.0000...
# Epoch 4/15... Loss: 0.0344... Acc: 0.9900...
# Epoch 4/15... Loss: 0.0141... Acc: 0.9900...
# Epoch 4/15... Loss: 0.0355... Acc: 0.9900...
# Epoch 4/15... Loss: 0.0441... Acc: 0.9800...
# Epoch 4/15... Loss: 0.0275... Acc: 0.9900...
# Epoch 4/15... Loss: 0.0256... Acc: 0.9800...
# Epoch 5/15... Loss: 0.0140... Acc: 1.0000...
# Epoch 5/15... Loss: 0.0265... Acc: 0.9900...
# Epoch 5/15... Loss: 0.0471... Acc: 0.9800...
# Epoch 5/15... Loss: 0.0563... Acc: 0.9700...
# Epoch 5/15... Loss: 0.0033... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0043... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0287... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0118... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0182... Acc: 0.9900...
# Epoch 6/15... Loss: 0.0287... Acc: 0.9800...
# Epoch 6/15... Loss: 0.0147... Acc: 1.0000...
# Epoch 7/15... Loss: 0.0089... Acc: 1.0000...
# Epoch 7/15... Loss: 0.0181... Acc: 0.9900...
# Epoch 7/15... Loss: 0.0206... Acc: 0.9800...
# Epoch 7/15... Loss: 0.0061... Acc: 1.0000...
# Epoch 7/15... Loss: 0.0075... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0056... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0729... Acc: 0.9800...
# Epoch 8/15... Loss: 0.0070... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0081... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0070... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0016... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0100... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0015... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0045... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0025... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0142... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0405... Acc: 0.9800...
# Epoch 10/15... Loss: 0.0141... Acc: 0.9900...
# Epoch 10/15... Loss: 0.0058... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0103... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0041... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0084... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0070... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0051... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0047... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0077... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0061... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0023... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0046... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0342... Acc: 0.9800...
# Epoch 12/15... Loss: 0.0012... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0429... Acc: 0.9800...
# Epoch 12/15... Loss: 0.0362... Acc: 0.9800...
# Epoch 13/15... Loss: 0.0017... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0049... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0202... Acc: 0.9900...
# Epoch 13/15... Loss: 0.0508... Acc: 0.9800...
# Epoch 13/15... Loss: 0.0044... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0147... Acc: 0.9900...
# Epoch 14/15... Loss: 0.0012... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0026... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0077... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0021... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0048... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0229... Acc: 0.9900...
# Epoch 15/15... Loss: 0.0016... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0025... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0012... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0016... Acc: 1.0000...
# [Running]: he.false!!!
# Epoch 1/15... Loss: 0.2630... Acc: 0.9200...
# Epoch 1/15... Loss: 0.1644... Acc: 0.9600...
# Epoch 1/15... Loss: 0.1605... Acc: 0.9600...
# Epoch 1/15... Loss: 0.0839... Acc: 0.9800...
# Epoch 1/15... Loss: 0.0716... Acc: 0.9900...
# Epoch 2/15... Loss: 0.0435... Acc: 0.9900...
# Epoch 2/15... Loss: 0.1730... Acc: 0.9600...
# Epoch 2/15... Loss: 0.1013... Acc: 0.9900...
# Epoch 2/15... Loss: 0.1366... Acc: 0.9600...
# Epoch 2/15... Loss: 0.0575... Acc: 0.9700...
# Epoch 2/15... Loss: 0.1401... Acc: 0.9700...
# Epoch 3/15... Loss: 0.1461... Acc: 0.9700...
# Epoch 3/15... Loss: 0.0404... Acc: 0.9900...
# Epoch 3/15... Loss: 0.0533... Acc: 0.9800...
# Epoch 3/15... Loss: 0.0754... Acc: 0.9600...
# Epoch 3/15... Loss: 0.0413... Acc: 0.9800...
# Epoch 4/15... Loss: 0.0167... Acc: 1.0000...
# Epoch 4/15... Loss: 0.0799... Acc: 0.9600...
# Epoch 4/15... Loss: 0.0421... Acc: 0.9900...
# Epoch 4/15... Loss: 0.0116... Acc: 1.0000...
# Epoch 4/15... Loss: 0.0355... Acc: 0.9900...
# Epoch 4/15... Loss: 0.0405... Acc: 0.9700...
# Epoch 5/15... Loss: 0.0502... Acc: 0.9800...
# Epoch 5/15... Loss: 0.0121... Acc: 1.0000...
# Epoch 5/15... Loss: 0.0078... Acc: 1.0000...
# Epoch 5/15... Loss: 0.0153... Acc: 1.0000...
# Epoch 5/15... Loss: 0.0485... Acc: 0.9900...
# Epoch 6/15... Loss: 0.0093... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0032... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0165... Acc: 1.0000...
# Epoch 6/15... Loss: 0.0426... Acc: 0.9800...
# Epoch 6/15... Loss: 0.0732... Acc: 0.9900...
# Epoch 6/15... Loss: 0.0158... Acc: 1.0000...
# Epoch 7/15... Loss: 0.0018... Acc: 1.0000...
# Epoch 7/15... Loss: 0.0051... Acc: 1.0000...
# Epoch 7/15... Loss: 0.0173... Acc: 0.9900...
# Epoch 7/15... Loss: 0.0213... Acc: 0.9900...
# Epoch 7/15... Loss: 0.0034... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0182... Acc: 0.9900...
# Epoch 8/15... Loss: 0.0136... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0027... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0166... Acc: 0.9900...
# Epoch 8/15... Loss: 0.0014... Acc: 1.0000...
# Epoch 8/15... Loss: 0.0028... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0043... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0126... Acc: 1.0000...
# Epoch 9/15... Loss: 0.0388... Acc: 0.9900...
# Epoch 9/15... Loss: 0.0269... Acc: 0.9900...
# Epoch 9/15... Loss: 0.0111... Acc: 0.9900...
# Epoch 10/15... Loss: 0.0029... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0019... Acc: 1.0000...
# Epoch 10/15... Loss: 0.0321... Acc: 0.9800...
# Epoch 10/15... Loss: 0.0134... Acc: 0.9900...
# Epoch 10/15... Loss: 0.0308... Acc: 0.9900...
# Epoch 10/15... Loss: 0.0255... Acc: 0.9900...
# Epoch 11/15... Loss: 0.0069... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0039... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0199... Acc: 0.9900...
# Epoch 11/15... Loss: 0.0072... Acc: 1.0000...
# Epoch 11/15... Loss: 0.0567... Acc: 0.9800...
# Epoch 12/15... Loss: 0.0021... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0095... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0028... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0417... Acc: 0.9800...
# Epoch 12/15... Loss: 0.0093... Acc: 1.0000...
# Epoch 12/15... Loss: 0.0337... Acc: 0.9900...
# Epoch 13/15... Loss: 0.0011... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0002... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0009... Acc: 1.0000...
# Epoch 13/15... Loss: 0.0131... Acc: 0.9900...
# Epoch 13/15... Loss: 0.0146... Acc: 0.9900...
# Epoch 14/15... Loss: 0.0096... Acc: 0.9900...
# Epoch 14/15... Loss: 0.0033... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0021... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0018... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0039... Acc: 1.0000...
# Epoch 14/15... Loss: 0.0008... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0002... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0005... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0126... Acc: 0.9900...
# Epoch 15/15... Loss: 0.0053... Acc: 1.0000...
# Epoch 15/15... Loss: 0.0184... Acc: 0.9900...

# %%
for k, v in results.items():
    if isinstance(v, dict):
        print('name: {}, loss: {}, acc: {}'.format(k, len(v['loss']), len(v['acc'])))
# Out:
# name: he.true, loss: 82, acc: 82
# name: he.false, loss: 82, acc: 82
# name: normal.false, loss: 82, acc: 82
# name: truncated.true, loss: 82, acc: 82
# name: truncated.false, loss: 82, acc: 82
# name: xavier.false, loss: 82, acc: 82
# name: normal.true, loss: 82, acc: 82
# name: xavier.true, loss: 82, acc: 82

# %%
fig, ax = plt.subplots()
for k, v in results.items():
    if isinstance(v, dict):
        losses = np.array(v['loss'])
        plt.plot(losses, label=k)
plt.title("Training Losses")
plt.legend()

# %%
fig, ax = plt.subplots()
for k, v in results.items():
    if isinstance(v, dict):
        accuracy = np.array(v['acc'])
        plt.plot(accuracy, label=k)
plt.title("Training Accuracies")
plt.legend()
