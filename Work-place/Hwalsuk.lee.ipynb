# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

RANGE = 5


# p_d(x)
class DataDistribution(object):
    def __init__(self, mu, sigma):
        self.mu = mu
        self.sigma = sigma

    def sample(self, N):
        samples = np.random.normal(self.mu, self.sigma, N)
        samples.sort()
        return samples


# p_z(z)
class NoiseDistribution(object):
    def __init__(self, range):
        self.range = range

    # equally spaced samples + noise
    def sample(self, N):
        offset = np.random.random(N) * (float(self.range) / N)
        samples = np.linspace(-self.range, self.range, N) + offset
        return samples


# G(z)
def generator(x, n_hidden=32):

    # initializers
    w_init = tf.truncated_normal_initializer(stddev=2)
    b_init = tf.constant_initializer(0.)

    # 1st hidden layer
    w0 = tf.get_variable('w0', [x.get_shape()[1], n_hidden], initializer=w_init)
    b0 = tf.get_variable('b0', [n_hidden], initializer=b_init)
    h0 = tf.nn.relu(tf.matmul(x, w0) + b0)

    # output layer
    w1 = tf.get_variable('w1', [h0.get_shape()[1], 1], initializer=w_init)
    b1 = tf.get_variable('b1', [1], initializer=b_init)
    o = tf.matmul(h0, w1) + b1

    return o


# D(x)
def discriminator(x, n_hidden=32):

    # initializers
    w_init = tf.contrib.layers.variance_scaling_initializer()
    b_init = tf.constant_initializer(0.)

    # 1st hidden layer
    w0 = tf.get_variable('w0', [x.get_shape()[1], n_hidden], initializer=w_init)
    b0 = tf.get_variable('b0', [n_hidden], initializer=b_init)
    h0 = tf.nn.relu(tf.matmul(x, w0) + b0)

    # output layer
    w1 = tf.get_variable('w1', [h0.get_shape()[1], 1], initializer=w_init)
    b1 = tf.get_variable('b1', [1], initializer=b_init)
    o = tf.sigmoid(tf.matmul(h0, w1) + b1)

    return o


# re-used for optimizing all networks
def optimizer(loss, var_list, num_decay_steps=400, initial_learning_rate=0.03):
    decay = 0.95
    batch = tf.Variable(0)
    learning_rate = tf.train.exponential_decay(
        initial_learning_rate,
        batch,
        num_decay_steps,
        decay,
        staircase=True
    )
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(
        loss,
        global_step=batch,
        var_list=var_list
    )
    return optimizer


# plot decision boundaries (init, pre-trained, trained) and p_data, p_g
class ResultPlot(object):
    def __init__(self, num_points, num_bins, mu, sigma):
        self.num_points = num_points    # number of data points to be evaluated
        self.num_bins = num_bins        # number of bins to get histogram

        self.mu = mu                    # mu of p_data
        self.sigma = sigma              # sigma of p_data

        self.xs = np.linspace(-RANGE, RANGE, num_points)    # positions of data
        self.bins = np.linspace(-RANGE, RANGE, num_bins)    # positions of bins

    def show_results(self, db_init, db_pre_trained, db_trained, pd, pg, save_img=True):
        db_x = np.linspace(-RANGE, RANGE, len(db_trained))
        p_x = np.linspace(-RANGE, RANGE, len(pd))
        f, ax = plt.subplots(1)
        ax.plot(db_x, db_init, 'g--', linewidth=2, label='db_init')
        ax.plot(db_x, db_pre_trained, 'c--', linewidth=2, label='db_pre_trained')
        ax.plot(db_x, db_trained, 'g-', linewidth=2, label='db_trained')
        ax.set_ylim(0, max(1, np.max(pd) * 1.1))
        ax.set_xlim(max(self.mu - self.sigma * 3, -RANGE * 0.9), min(self.mu + self.sigma * 3, RANGE * 0.9))
        plt.plot(p_x, pd, 'b-', linewidth=2, label='real data')
        plt.plot(p_x, pg, 'r-', linewidth=2, label='generated data')
        plt.title('1D Generative Adversarial Network: ' + '(mu : %3g,' % self.mu + ' sigma : %3g)' % self.sigma)
        plt.xlabel('Data values')
        plt.ylabel('Probability density')
        plt.legend()
        plt.grid(True)

        if save_img:
            plt.savefig('GAN_1d_gaussian' + '_mu_%g' % self.mu + '_sigma_%g' % self.sigma + '.png')

        plt.show()


def main():
    """ parameters """
    # p_data
    mu = 0
    sigma = 1

    # training
    B = 150                 # batch-size
    LR = 0.03               # learning rate (generator uses half of this)
    TRAIN_ITERS = 3000      # number of iterations

    # network
    n_hidden = 32           # number of hidden layers

    """ build graph """

    # networks : pre-trained discriminator
    with tf.variable_scope('D_pre'):
        pre_input = tf.placeholder(tf.float32, shape=(None, 1))
        pre_labels = tf.placeholder(tf.float32, shape=(None, 1))
        D_pre = discriminator(pre_input, n_hidden)

    # networks : generator
    with tf.variable_scope('Gen'):
        z = tf.placeholder(tf.float32, shape=(None, 1))
        G_z = generator(z, n_hidden)

    # networks : discriminator
    with tf.variable_scope('Disc') as scope:
        x = tf.placeholder(tf.float32, shape=(None, 1))
        D_real = discriminator(x, n_hidden)
        scope.reuse_variables()
        D_fake = discriminator(G_z, n_hidden)

    # loss for each network
    eps = 1e-2  # to prevent log(0) case
    pre_loss = tf.reduce_mean(tf.square(D_pre - pre_labels))
    loss_g = tf.reduce_mean(-tf.log(D_fake + eps))
    loss_d = tf.reduce_mean(-tf.log(D_real + eps) - tf.log(1 - D_fake + eps))

    # trainable variables for each network
    d_pre_params = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope='D_pre')
    d_params = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope='Disc')
    g_params = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope='Gen')

    # optimizer for each network
    pre_opt = optimizer(pre_loss, d_pre_params, 400, LR)
    opt_d = optimizer(loss_d, d_params, 400, LR)
    opt_g = optimizer(loss_g, g_params, 400, LR / 2)

    """ training """

    # open session and initialize all variables
    sess = tf.InteractiveSession()
    tf.global_variables_initializer().run()

    # sources
    p_data = DataDistribution(mu, sigma)
    p_z = NoiseDistribution(RANGE)

    # class for result-plot
    plot = ResultPlot(10000, 20, mu, sigma)

    # plot : initial decision boundary
    db_init = np.zeros((plot.num_points, 1))
    for i in range(plot.num_points // B):
        db_init[B * i:B * (i + 1)] = sess.run(D_real, {x: np.reshape(plot.xs[B * i:B * (i + 1)], (B, 1))})

    # pre-training discriminator
    num_pretrain_steps = 1000
    for step in range(num_pretrain_steps):

        print('pre-training :  %d/%d' % (step + 1, num_pretrain_steps))

        # Object of pre-training is to make decision boundary as similar as pdf of data (i.e. p_data)
        # Since p_data is unknown in real situation, we get histogram and estimate pdf
        N = 1000
        d = p_data.sample(N)
        n_bins = 100
        histc, edges = np.histogram(d, bins=n_bins, density=True)

        # Estimated pdf is used as labels after normalization
        max_histc = np.max(histc)
        min_histc = np.min(histc)
        labels = (histc - min_histc) / (max_histc - min_histc)
        d = edges[1:]

        # Execute one training step
        sess.run([pre_loss, pre_opt],
                 {pre_input: np.reshape(d, (n_bins, 1)), pre_labels: np.reshape(labels, (n_bins, 1))})
    print('pre-training finished!')

    # store pre-trained variables
    weightsD = sess.run(d_pre_params)

    # copy weights from pre-training over to new D network
    tf.global_variables_initializer().run()
    for i, v in enumerate(d_params):
        sess.run(v.assign(weightsD[i]))

    # plot : pre-trained decision boundary
    db_pre_trained = np.zeros((plot.num_points, 1))
    for i in range(plot.num_points // B):
        db_pre_trained[B * i:B * (i + 1)] = sess.run(D_real, {x: np.reshape(plot.xs[B * i:B * (i + 1)], (B, 1))})

    # training-loop
    for step in range(TRAIN_ITERS):

        np.random.seed(np.random.randint(0, TRAIN_ITERS))

        # update discriminator
        x_ = p_data.sample(B)
        z_ = p_z.sample(B)

        loss_d_, _ = sess.run([loss_d, opt_d], {x: np.reshape(x_, (B, 1)), z: np.reshape(z_, (B, 1))})

        # update generator
        z_ = p_z.sample(B)
        loss_g_, _ = sess.run([loss_g, opt_g], {z: np.reshape(z_, (B, 1))})

        if step % 10 == 0:
            print('[%d/%d]: loss_d : %.3f, loss_g : %.3f' % (step, TRAIN_ITERS, loss_d_, loss_g_))

    """ show results """

    # plot : trained decision boundary
    db_trained = np.zeros((plot.num_points, 1))
    for i in range(plot.num_points // B):
        db_trained[B * i:B * (i + 1)] = sess.run(D_real, {x: np.reshape(plot.xs[B * i:B * (i + 1)], (B, 1))})

    # plot : pdf of data distribution
    d = p_data.sample(plot.num_points)
    pd, _ = np.histogram(d, bins=plot.bins, density=True)

    # plot : pdf of generated samples
    zs = np.linspace(-RANGE, RANGE, plot.num_points)
    g = np.zeros((plot.num_points, 1))
    for i in range(plot.num_points // B):
        g[B * i:B * (i + 1)] = sess.run(G_z, {z: np.reshape(zs[B * i:B * (i + 1)], (B, 1))})
    pg, _ = np.histogram(g, bins=plot.bins, density=True)

    # plot results
    plot.show_results(db_init, db_pre_trained, db_trained, pd, pg, save_img=True)

    sess.close()


if __name__ == '__main__':
    main()
# Out:
# pre-training :  1/1000
# pre-training :  2/1000
# pre-training :  3/1000
# pre-training :  4/1000
# pre-training :  5/1000
# pre-training :  6/1000
# pre-training :  7/1000
# pre-training :  8/1000
# pre-training :  9/1000
# pre-training :  10/1000
# pre-training :  11/1000
# pre-training :  12/1000
# pre-training :  13/1000
# pre-training :  14/1000
# pre-training :  15/1000
# pre-training :  16/1000
# pre-training :  17/1000
# pre-training :  18/1000
# pre-training :  19/1000
# pre-training :  20/1000
# pre-training :  21/1000
# pre-training :  22/1000
# pre-training :  23/1000
# pre-training :  24/1000
# pre-training :  25/1000
# pre-training :  26/1000
# pre-training :  27/1000
# pre-training :  28/1000
# pre-training :  29/1000
# pre-training :  30/1000
# pre-training :  31/1000
# pre-training :  32/1000
# pre-training :  33/1000
# pre-training :  34/1000
# pre-training :  35/1000
# pre-training :  36/1000
# pre-training :  37/1000
# pre-training :  38/1000
# pre-training :  39/1000
# pre-training :  40/1000
# pre-training :  41/1000
# pre-training :  42/1000
# pre-training :  43/1000
# pre-training :  44/1000
# pre-training :  45/1000
# pre-training :  46/1000
# pre-training :  47/1000
# pre-training :  48/1000
# pre-training :  49/1000
# pre-training :  50/1000
# pre-training :  51/1000
# pre-training :  52/1000
# pre-training :  53/1000
# pre-training :  54/1000
# pre-training :  55/1000
# pre-training :  56/1000
# pre-training :  57/1000
# pre-training :  58/1000
# pre-training :  59/1000
# pre-training :  60/1000
# pre-training :  61/1000
# pre-training :  62/1000
# pre-training :  63/1000
# pre-training :  64/1000
# pre-training :  65/1000
# pre-training :  66/1000
# pre-training :  67/1000
# pre-training :  68/1000
# pre-training :  69/1000
# pre-training :  70/1000
# pre-training :  71/1000
# pre-training :  72/1000
# pre-training :  73/1000
# pre-training :  74/1000
# pre-training :  75/1000
# pre-training :  76/1000
# pre-training :  77/1000
# pre-training :  78/1000
# pre-training :  79/1000
# pre-training :  80/1000
# pre-training :  81/1000
# pre-training :  82/1000
# pre-training :  83/1000
# pre-training :  84/1000
# pre-training :  85/1000
# pre-training :  86/1000
# pre-training :  87/1000
# pre-training :  88/1000
# pre-training :  89/1000
# pre-training :  90/1000
# pre-training :  91/1000
# pre-training :  92/1000
# pre-training :  93/1000
# pre-training :  94/1000
# pre-training :  95/1000
# pre-training :  96/1000
# pre-training :  97/1000
# pre-training :  98/1000
# pre-training :  99/1000
# pre-training :  100/1000
# pre-training :  101/1000
# pre-training :  102/1000
# pre-training :  103/1000
# pre-training :  104/1000
# pre-training :  105/1000
# pre-training :  106/1000
# pre-training :  107/1000
# pre-training :  108/1000
# pre-training :  109/1000
# pre-training :  110/1000
# pre-training :  111/1000
# pre-training :  112/1000
# pre-training :  113/1000
# pre-training :  114/1000
# pre-training :  115/1000
# pre-training :  116/1000
# pre-training :  117/1000
# pre-training :  118/1000
# pre-training :  119/1000
# pre-training :  120/1000
# pre-training :  121/1000
# pre-training :  122/1000
# pre-training :  123/1000
# pre-training :  124/1000
# pre-training :  125/1000
# pre-training :  126/1000
# pre-training :  127/1000
# pre-training :  128/1000
# pre-training :  129/1000
# pre-training :  130/1000
# pre-training :  131/1000
# pre-training :  132/1000
# pre-training :  133/1000
# pre-training :  134/1000
# pre-training :  135/1000
# pre-training :  136/1000
# pre-training :  137/1000
# pre-training :  138/1000
# pre-training :  139/1000
# pre-training :  140/1000
# pre-training :  141/1000
# pre-training :  142/1000
# pre-training :  143/1000
# pre-training :  144/1000
# pre-training :  145/1000
# pre-training :  146/1000
# pre-training :  147/1000
# pre-training :  148/1000
# pre-training :  149/1000
# pre-training :  150/1000
# pre-training :  151/1000
# pre-training :  152/1000
# pre-training :  153/1000
# pre-training :  154/1000
# pre-training :  155/1000
# pre-training :  156/1000
# pre-training :  157/1000
# pre-training :  158/1000
# pre-training :  159/1000
# pre-training :  160/1000
# pre-training :  161/1000
# pre-training :  162/1000
# pre-training :  163/1000
# pre-training :  164/1000
# pre-training :  165/1000
# pre-training :  166/1000
# pre-training :  167/1000
# pre-training :  168/1000
# pre-training :  169/1000
# pre-training :  170/1000
# pre-training :  171/1000
# pre-training :  172/1000
# pre-training :  173/1000
# pre-training :  174/1000
# pre-training :  175/1000
# pre-training :  176/1000
# pre-training :  177/1000
# pre-training :  178/1000
# pre-training :  179/1000
# pre-training :  180/1000
# pre-training :  181/1000
# pre-training :  182/1000
# pre-training :  183/1000
# pre-training :  184/1000
# pre-training :  185/1000
# pre-training :  186/1000
# pre-training :  187/1000
# pre-training :  188/1000
# pre-training :  189/1000
# pre-training :  190/1000
# pre-training :  191/1000
# pre-training :  192/1000
# pre-training :  193/1000
# pre-training :  194/1000
# pre-training :  195/1000
# pre-training :  196/1000
# pre-training :  197/1000
# pre-training :  198/1000
# pre-training :  199/1000
# pre-training :  200/1000
# pre-training :  201/1000
# pre-training :  202/1000
# pre-training :  203/1000
# pre-training :  204/1000
# pre-training :  205/1000
# pre-training :  206/1000
# pre-training :  207/1000
# pre-training :  208/1000
# pre-training :  209/1000
# pre-training :  210/1000
# pre-training :  211/1000
# pre-training :  212/1000
# pre-training :  213/1000
# pre-training :  214/1000
# pre-training :  215/1000
# pre-training :  216/1000
# pre-training :  217/1000
# pre-training :  218/1000
# pre-training :  219/1000
# pre-training :  220/1000
# pre-training :  221/1000
# pre-training :  222/1000
# pre-training :  223/1000
# pre-training :  224/1000
# pre-training :  225/1000
# pre-training :  226/1000
# pre-training :  227/1000
# pre-training :  228/1000
# pre-training :  229/1000
# pre-training :  230/1000
# pre-training :  231/1000
# pre-training :  232/1000
# pre-training :  233/1000
# pre-training :  234/1000
# pre-training :  235/1000
# pre-training :  236/1000
# pre-training :  237/1000
# pre-training :  238/1000
# pre-training :  239/1000
# pre-training :  240/1000
# pre-training :  241/1000
# pre-training :  242/1000
# pre-training :  243/1000
# pre-training :  244/1000
# pre-training :  245/1000
# pre-training :  246/1000
# pre-training :  247/1000
# pre-training :  248/1000
# pre-training :  249/1000
# pre-training :  250/1000
# pre-training :  251/1000
# pre-training :  252/1000
# pre-training :  253/1000
# pre-training :  254/1000
# pre-training :  255/1000
# pre-training :  256/1000
# pre-training :  257/1000
# pre-training :  258/1000
# pre-training :  259/1000
# pre-training :  260/1000
# pre-training :  261/1000
# pre-training :  262/1000
# pre-training :  263/1000
# pre-training :  264/1000
# pre-training :  265/1000
# pre-training :  266/1000
# pre-training :  267/1000
# pre-training :  268/1000
# pre-training :  269/1000
# pre-training :  270/1000
# pre-training :  271/1000
# pre-training :  272/1000
# pre-training :  273/1000
# pre-training :  274/1000
# pre-training :  275/1000
# pre-training :  276/1000
# pre-training :  277/1000
# pre-training :  278/1000
# pre-training :  279/1000
# pre-training :  280/1000
# pre-training :  281/1000
# pre-training :  282/1000
# pre-training :  283/1000
# pre-training :  284/1000
# pre-training :  285/1000
# pre-training :  286/1000
# pre-training :  287/1000
# pre-training :  288/1000
# pre-training :  289/1000
# pre-training :  290/1000
# pre-training :  291/1000
# pre-training :  292/1000
# pre-training :  293/1000
# pre-training :  294/1000
# pre-training :  295/1000
# pre-training :  296/1000
# pre-training :  297/1000
# pre-training :  298/1000
# pre-training :  299/1000
# pre-training :  300/1000
# pre-training :  301/1000
# pre-training :  302/1000
# pre-training :  303/1000
# pre-training :  304/1000
# pre-training :  305/1000
# pre-training :  306/1000
# pre-training :  307/1000
# pre-training :  308/1000
# pre-training :  309/1000
# pre-training :  310/1000
# pre-training :  311/1000
# pre-training :  312/1000
# pre-training :  313/1000
# pre-training :  314/1000
# pre-training :  315/1000
# pre-training :  316/1000
# pre-training :  317/1000
# pre-training :  318/1000
# pre-training :  319/1000
# pre-training :  320/1000
# pre-training :  321/1000
# pre-training :  322/1000
# pre-training :  323/1000
# pre-training :  324/1000
# pre-training :  325/1000
# pre-training :  326/1000
# pre-training :  327/1000
# pre-training :  328/1000
# pre-training :  329/1000
# pre-training :  330/1000
# pre-training :  331/1000
# pre-training :  332/1000
# pre-training :  333/1000
# pre-training :  334/1000
# pre-training :  335/1000
# pre-training :  336/1000
# pre-training :  337/1000
# pre-training :  338/1000
# pre-training :  339/1000
# pre-training :  340/1000
# pre-training :  341/1000
# pre-training :  342/1000
# pre-training :  343/1000
# pre-training :  344/1000
# pre-training :  345/1000
# pre-training :  346/1000
# pre-training :  347/1000
# pre-training :  348/1000
# pre-training :  349/1000
# pre-training :  350/1000
# pre-training :  351/1000
# pre-training :  352/1000
# pre-training :  353/1000
# pre-training :  354/1000
# pre-training :  355/1000
# pre-training :  356/1000
# pre-training :  357/1000
# pre-training :  358/1000
# pre-training :  359/1000
# pre-training :  360/1000
# pre-training :  361/1000
# pre-training :  362/1000
# pre-training :  363/1000
# pre-training :  364/1000
# pre-training :  365/1000
# pre-training :  366/1000
# pre-training :  367/1000
# pre-training :  368/1000
# pre-training :  369/1000
# pre-training :  370/1000
# pre-training :  371/1000
# pre-training :  372/1000
# pre-training :  373/1000
# pre-training :  374/1000
# pre-training :  375/1000
# pre-training :  376/1000
# pre-training :  377/1000
# pre-training :  378/1000
# pre-training :  379/1000
# pre-training :  380/1000
# pre-training :  381/1000
# pre-training :  382/1000
# pre-training :  383/1000
# pre-training :  384/1000
# pre-training :  385/1000
# pre-training :  386/1000
# pre-training :  387/1000
# pre-training :  388/1000
# pre-training :  389/1000
# pre-training :  390/1000
# pre-training :  391/1000
# pre-training :  392/1000
# pre-training :  393/1000
# pre-training :  394/1000
# pre-training :  395/1000
# pre-training :  396/1000
# pre-training :  397/1000
# pre-training :  398/1000
# pre-training :  399/1000
# pre-training :  400/1000
# pre-training :  401/1000
# pre-training :  402/1000
# pre-training :  403/1000
# pre-training :  404/1000
# pre-training :  405/1000
# pre-training :  406/1000
# pre-training :  407/1000
# pre-training :  408/1000
# pre-training :  409/1000
# pre-training :  410/1000
# pre-training :  411/1000
# pre-training :  412/1000
# pre-training :  413/1000
# pre-training :  414/1000
# pre-training :  415/1000
# pre-training :  416/1000
# pre-training :  417/1000
# pre-training :  418/1000
# pre-training :  419/1000
# pre-training :  420/1000
# pre-training :  421/1000
# pre-training :  422/1000
# pre-training :  423/1000
# pre-training :  424/1000
# pre-training :  425/1000
# pre-training :  426/1000
# pre-training :  427/1000
# pre-training :  428/1000
# pre-training :  429/1000
# pre-training :  430/1000
# pre-training :  431/1000
# pre-training :  432/1000
# pre-training :  433/1000
# pre-training :  434/1000
# pre-training :  435/1000
# pre-training :  436/1000
# pre-training :  437/1000
# pre-training :  438/1000
# pre-training :  439/1000
# pre-training :  440/1000
# pre-training :  441/1000
# pre-training :  442/1000
# pre-training :  443/1000
# pre-training :  444/1000
# pre-training :  445/1000
# pre-training :  446/1000
# pre-training :  447/1000
# pre-training :  448/1000
# pre-training :  449/1000
# pre-training :  450/1000
# pre-training :  451/1000
# pre-training :  452/1000
# pre-training :  453/1000
# pre-training :  454/1000
# pre-training :  455/1000
# pre-training :  456/1000
# pre-training :  457/1000
# pre-training :  458/1000
# pre-training :  459/1000
# pre-training :  460/1000
# pre-training :  461/1000
# pre-training :  462/1000
# pre-training :  463/1000
# pre-training :  464/1000
# pre-training :  465/1000
# pre-training :  466/1000
# pre-training :  467/1000
# pre-training :  468/1000
# pre-training :  469/1000
# pre-training :  470/1000
# pre-training :  471/1000
# pre-training :  472/1000
# pre-training :  473/1000
# pre-training :  474/1000
# pre-training :  475/1000
# pre-training :  476/1000
# pre-training :  477/1000
# pre-training :  478/1000
# pre-training :  479/1000
# pre-training :  480/1000
# pre-training :  481/1000
# pre-training :  482/1000
# pre-training :  483/1000
# pre-training :  484/1000
# pre-training :  485/1000
# pre-training :  486/1000
# pre-training :  487/1000
# pre-training :  488/1000
# pre-training :  489/1000
# pre-training :  490/1000
# pre-training :  491/1000
# pre-training :  492/1000
# pre-training :  493/1000
# pre-training :  494/1000
# pre-training :  495/1000
# pre-training :  496/1000
# pre-training :  497/1000
# pre-training :  498/1000
# pre-training :  499/1000
# pre-training :  500/1000
# pre-training :  501/1000
# pre-training :  502/1000
# pre-training :  503/1000
# pre-training :  504/1000
# pre-training :  505/1000
# pre-training :  506/1000
# pre-training :  507/1000
# pre-training :  508/1000
# pre-training :  509/1000
# pre-training :  510/1000
# pre-training :  511/1000
# pre-training :  512/1000
# pre-training :  513/1000
# pre-training :  514/1000
# pre-training :  515/1000
# pre-training :  516/1000
# pre-training :  517/1000
# pre-training :  518/1000
# pre-training :  519/1000
# pre-training :  520/1000
# pre-training :  521/1000
# pre-training :  522/1000
# pre-training :  523/1000
# pre-training :  524/1000
# pre-training :  525/1000
# pre-training :  526/1000
# pre-training :  527/1000
# pre-training :  528/1000
# pre-training :  529/1000
# pre-training :  530/1000
# pre-training :  531/1000
# pre-training :  532/1000
# pre-training :  533/1000
# pre-training :  534/1000
# pre-training :  535/1000
# pre-training :  536/1000
# pre-training :  537/1000
# pre-training :  538/1000
# pre-training :  539/1000
# pre-training :  540/1000
# pre-training :  541/1000
# pre-training :  542/1000
# pre-training :  543/1000
# pre-training :  544/1000
# pre-training :  545/1000
# pre-training :  546/1000
# pre-training :  547/1000
# pre-training :  548/1000
# pre-training :  549/1000
# pre-training :  550/1000
# pre-training :  551/1000
# pre-training :  552/1000
# pre-training :  553/1000
# pre-training :  554/1000
# pre-training :  555/1000
# pre-training :  556/1000
# pre-training :  557/1000
# pre-training :  558/1000
# pre-training :  559/1000
# pre-training :  560/1000
# pre-training :  561/1000
# pre-training :  562/1000
# pre-training :  563/1000
# pre-training :  564/1000
# pre-training :  565/1000
# pre-training :  566/1000
# pre-training :  567/1000
# pre-training :  568/1000
# pre-training :  569/1000
# pre-training :  570/1000
# pre-training :  571/1000
# pre-training :  572/1000
# pre-training :  573/1000
# pre-training :  574/1000
# pre-training :  575/1000
# pre-training :  576/1000
# pre-training :  577/1000
# pre-training :  578/1000
# pre-training :  579/1000
# pre-training :  580/1000
# pre-training :  581/1000
# pre-training :  582/1000
# pre-training :  583/1000
# pre-training :  584/1000
# pre-training :  585/1000
# pre-training :  586/1000
# pre-training :  587/1000
# pre-training :  588/1000
# pre-training :  589/1000
# pre-training :  590/1000
# pre-training :  591/1000
# pre-training :  592/1000
# pre-training :  593/1000
# pre-training :  594/1000
# pre-training :  595/1000
# pre-training :  596/1000
# pre-training :  597/1000
# pre-training :  598/1000
# pre-training :  599/1000
# pre-training :  600/1000
# pre-training :  601/1000
# pre-training :  602/1000
# pre-training :  603/1000
# pre-training :  604/1000
# pre-training :  605/1000
# pre-training :  606/1000
# pre-training :  607/1000
# pre-training :  608/1000
# pre-training :  609/1000
# pre-training :  610/1000
# pre-training :  611/1000
# pre-training :  612/1000
# pre-training :  613/1000
# pre-training :  614/1000
# pre-training :  615/1000
# pre-training :  616/1000
# pre-training :  617/1000
# pre-training :  618/1000
# pre-training :  619/1000
# pre-training :  620/1000
# pre-training :  621/1000
# pre-training :  622/1000
# pre-training :  623/1000
# pre-training :  624/1000
# pre-training :  625/1000
# pre-training :  626/1000
# pre-training :  627/1000
# pre-training :  628/1000
# pre-training :  629/1000
# pre-training :  630/1000
# pre-training :  631/1000
# pre-training :  632/1000
# pre-training :  633/1000
# pre-training :  634/1000
# pre-training :  635/1000
# pre-training :  636/1000
# pre-training :  637/1000
# pre-training :  638/1000
# pre-training :  639/1000
# pre-training :  640/1000
# pre-training :  641/1000
# pre-training :  642/1000
# pre-training :  643/1000
# pre-training :  644/1000
# pre-training :  645/1000
# pre-training :  646/1000
# pre-training :  647/1000
# pre-training :  648/1000
# pre-training :  649/1000
# pre-training :  650/1000
# pre-training :  651/1000
# pre-training :  652/1000
# pre-training :  653/1000
# pre-training :  654/1000
# pre-training :  655/1000
# pre-training :  656/1000
# pre-training :  657/1000
# pre-training :  658/1000
# pre-training :  659/1000
# pre-training :  660/1000
# pre-training :  661/1000
# pre-training :  662/1000
# pre-training :  663/1000
# pre-training :  664/1000
# pre-training :  665/1000
# pre-training :  666/1000
# pre-training :  667/1000
# pre-training :  668/1000
# pre-training :  669/1000
# pre-training :  670/1000
# pre-training :  671/1000
# pre-training :  672/1000
# pre-training :  673/1000
# pre-training :  674/1000
# pre-training :  675/1000
# pre-training :  676/1000
# pre-training :  677/1000
# pre-training :  678/1000
# pre-training :  679/1000
# pre-training :  680/1000
# pre-training :  681/1000
# pre-training :  682/1000
# pre-training :  683/1000
# pre-training :  684/1000
# pre-training :  685/1000
# pre-training :  686/1000
# pre-training :  687/1000
# pre-training :  688/1000
# pre-training :  689/1000
# pre-training :  690/1000
# pre-training :  691/1000
# pre-training :  692/1000
# pre-training :  693/1000
# pre-training :  694/1000
# pre-training :  695/1000
# pre-training :  696/1000
# pre-training :  697/1000
# pre-training :  698/1000
# pre-training :  699/1000
# pre-training :  700/1000
# pre-training :  701/1000
# pre-training :  702/1000
# pre-training :  703/1000
# pre-training :  704/1000
# pre-training :  705/1000
# pre-training :  706/1000
# pre-training :  707/1000
# pre-training :  708/1000
# pre-training :  709/1000
# pre-training :  710/1000
# pre-training :  711/1000
# pre-training :  712/1000
# pre-training :  713/1000
# pre-training :  714/1000
# pre-training :  715/1000
# pre-training :  716/1000
# pre-training :  717/1000
# pre-training :  718/1000
# pre-training :  719/1000
# pre-training :  720/1000
# pre-training :  721/1000
# pre-training :  722/1000
# pre-training :  723/1000
# pre-training :  724/1000
# pre-training :  725/1000
# pre-training :  726/1000
# pre-training :  727/1000
# pre-training :  728/1000
# pre-training :  729/1000
# pre-training :  730/1000
# pre-training :  731/1000
# pre-training :  732/1000
# pre-training :  733/1000
# pre-training :  734/1000
# pre-training :  735/1000
# pre-training :  736/1000
# pre-training :  737/1000
# pre-training :  738/1000
# pre-training :  739/1000
# pre-training :  740/1000
# pre-training :  741/1000
# pre-training :  742/1000
# pre-training :  743/1000
# pre-training :  744/1000
# pre-training :  745/1000
# pre-training :  746/1000
# pre-training :  747/1000
# pre-training :  748/1000
# pre-training :  749/1000
# pre-training :  750/1000
# pre-training :  751/1000
# pre-training :  752/1000
# pre-training :  753/1000
# pre-training :  754/1000
# pre-training :  755/1000
# pre-training :  756/1000
# pre-training :  757/1000
# pre-training :  758/1000
# pre-training :  759/1000
# pre-training :  760/1000
# pre-training :  761/1000
# pre-training :  762/1000
# pre-training :  763/1000
# pre-training :  764/1000
# pre-training :  765/1000
# pre-training :  766/1000
# pre-training :  767/1000
# pre-training :  768/1000
# pre-training :  769/1000
# pre-training :  770/1000
# pre-training :  771/1000
# pre-training :  772/1000
# pre-training :  773/1000
# pre-training :  774/1000
# pre-training :  775/1000
# pre-training :  776/1000
# pre-training :  777/1000
# pre-training :  778/1000
# pre-training :  779/1000
# pre-training :  780/1000
# pre-training :  781/1000
# pre-training :  782/1000
# pre-training :  783/1000
# pre-training :  784/1000
# pre-training :  785/1000
# pre-training :  786/1000
# pre-training :  787/1000
# pre-training :  788/1000
# pre-training :  789/1000
# pre-training :  790/1000
# pre-training :  791/1000
# pre-training :  792/1000
# pre-training :  793/1000
# pre-training :  794/1000
# pre-training :  795/1000
# pre-training :  796/1000
# pre-training :  797/1000
# pre-training :  798/1000
# pre-training :  799/1000
# pre-training :  800/1000
# pre-training :  801/1000
# pre-training :  802/1000
# pre-training :  803/1000
# pre-training :  804/1000
# pre-training :  805/1000
# pre-training :  806/1000
# pre-training :  807/1000
# pre-training :  808/1000
# pre-training :  809/1000
# pre-training :  810/1000
# pre-training :  811/1000
# pre-training :  812/1000
# pre-training :  813/1000
# pre-training :  814/1000
# pre-training :  815/1000
# pre-training :  816/1000
# pre-training :  817/1000
# pre-training :  818/1000
# pre-training :  819/1000
# pre-training :  820/1000
# pre-training :  821/1000
# pre-training :  822/1000
# pre-training :  823/1000
# pre-training :  824/1000
# pre-training :  825/1000
# pre-training :  826/1000
# pre-training :  827/1000
# pre-training :  828/1000
# pre-training :  829/1000
# pre-training :  830/1000
# pre-training :  831/1000
# pre-training :  832/1000
# pre-training :  833/1000
# pre-training :  834/1000
# pre-training :  835/1000
# pre-training :  836/1000
# pre-training :  837/1000
# pre-training :  838/1000
# pre-training :  839/1000
# pre-training :  840/1000
# pre-training :  841/1000
# pre-training :  842/1000
# pre-training :  843/1000
# pre-training :  844/1000
# pre-training :  845/1000
# pre-training :  846/1000
# pre-training :  847/1000
# pre-training :  848/1000
# pre-training :  849/1000
# pre-training :  850/1000
# pre-training :  851/1000
# pre-training :  852/1000
# pre-training :  853/1000
# pre-training :  854/1000
# pre-training :  855/1000
# pre-training :  856/1000
# pre-training :  857/1000
# pre-training :  858/1000
# pre-training :  859/1000
# pre-training :  860/1000
# pre-training :  861/1000
# pre-training :  862/1000
# pre-training :  863/1000
# pre-training :  864/1000
# pre-training :  865/1000
# pre-training :  866/1000
# pre-training :  867/1000
# pre-training :  868/1000
# pre-training :  869/1000
# pre-training :  870/1000
# pre-training :  871/1000
# pre-training :  872/1000
# pre-training :  873/1000
# pre-training :  874/1000
# pre-training :  875/1000
# pre-training :  876/1000
# pre-training :  877/1000
# pre-training :  878/1000
# pre-training :  879/1000
# pre-training :  880/1000
# pre-training :  881/1000
# pre-training :  882/1000
# pre-training :  883/1000
# pre-training :  884/1000
# pre-training :  885/1000
# pre-training :  886/1000
# pre-training :  887/1000
# pre-training :  888/1000
# pre-training :  889/1000
# pre-training :  890/1000
# pre-training :  891/1000
# pre-training :  892/1000
# pre-training :  893/1000
# pre-training :  894/1000
# pre-training :  895/1000
# pre-training :  896/1000
# pre-training :  897/1000
# pre-training :  898/1000
# pre-training :  899/1000
# pre-training :  900/1000
# pre-training :  901/1000
# pre-training :  902/1000
# pre-training :  903/1000
# pre-training :  904/1000
# pre-training :  905/1000
# pre-training :  906/1000
# pre-training :  907/1000
# pre-training :  908/1000
# pre-training :  909/1000
# pre-training :  910/1000
# pre-training :  911/1000
# pre-training :  912/1000
# pre-training :  913/1000
# pre-training :  914/1000
# pre-training :  915/1000
# pre-training :  916/1000
# pre-training :  917/1000
# pre-training :  918/1000
# pre-training :  919/1000
# pre-training :  920/1000
# pre-training :  921/1000
# pre-training :  922/1000
# pre-training :  923/1000
# pre-training :  924/1000
# pre-training :  925/1000
# pre-training :  926/1000
# pre-training :  927/1000
# pre-training :  928/1000
# pre-training :  929/1000
# pre-training :  930/1000
# pre-training :  931/1000
# pre-training :  932/1000
# pre-training :  933/1000
# pre-training :  934/1000
# pre-training :  935/1000
# pre-training :  936/1000
# pre-training :  937/1000
# pre-training :  938/1000
# pre-training :  939/1000
# pre-training :  940/1000
# pre-training :  941/1000
# pre-training :  942/1000
# pre-training :  943/1000
# pre-training :  944/1000
# pre-training :  945/1000
# pre-training :  946/1000
# pre-training :  947/1000
# pre-training :  948/1000
# pre-training :  949/1000
# pre-training :  950/1000
# pre-training :  951/1000
# pre-training :  952/1000
# pre-training :  953/1000
# pre-training :  954/1000
# pre-training :  955/1000
# pre-training :  956/1000
# pre-training :  957/1000
# pre-training :  958/1000
# pre-training :  959/1000
# pre-training :  960/1000
# pre-training :  961/1000
# pre-training :  962/1000
# pre-training :  963/1000
# pre-training :  964/1000
# pre-training :  965/1000
# pre-training :  966/1000
# pre-training :  967/1000
# pre-training :  968/1000
# pre-training :  969/1000
# pre-training :  970/1000
# pre-training :  971/1000
# pre-training :  972/1000
# pre-training :  973/1000
# pre-training :  974/1000
# pre-training :  975/1000
# pre-training :  976/1000
# pre-training :  977/1000
# pre-training :  978/1000
# pre-training :  979/1000
# pre-training :  980/1000
# pre-training :  981/1000
# pre-training :  982/1000
# pre-training :  983/1000
# pre-training :  984/1000
# pre-training :  985/1000
# pre-training :  986/1000
# pre-training :  987/1000
# pre-training :  988/1000
# pre-training :  989/1000
# pre-training :  990/1000
# pre-training :  991/1000
# pre-training :  992/1000
# pre-training :  993/1000
# pre-training :  994/1000
# pre-training :  995/1000
# pre-training :  996/1000
# pre-training :  997/1000
# pre-training :  998/1000
# pre-training :  999/1000
# pre-training :  1000/1000
# pre-training finished!
# [0/3000]: loss_d : 0.940, loss_g : 3.333
# [10/3000]: loss_d : 0.843, loss_g : 2.616
# [20/3000]: loss_d : 0.871, loss_g : 2.523
# [30/3000]: loss_d : 0.847, loss_g : 2.441
# [40/3000]: loss_d : 0.808, loss_g : 2.560
# [50/3000]: loss_d : 0.822, loss_g : 2.461
# [60/3000]: loss_d : 1.189, loss_g : 1.325
# [70/3000]: loss_d : 1.581, loss_g : 0.397
# [80/3000]: loss_d : 1.620, loss_g : 0.382
# [90/3000]: loss_d : 1.417, loss_g : 0.609
# [100/3000]: loss_d : 1.588, loss_g : 0.413
# [110/3000]: loss_d : 1.448, loss_g : 0.543
# [120/3000]: loss_d : 1.464, loss_g : 0.589
# [130/3000]: loss_d : 1.351, loss_g : 0.781
# [140/3000]: loss_d : 1.414, loss_g : 0.672
# [150/3000]: loss_d : 1.417, loss_g : 0.719
# [160/3000]: loss_d : 1.412, loss_g : 0.649
# [170/3000]: loss_d : 1.464, loss_g : 0.475
# [180/3000]: loss_d : 1.416, loss_g : 0.446
# [190/3000]: loss_d : 1.394, loss_g : 0.483
# [200/3000]: loss_d : 1.381, loss_g : 0.511
# [210/3000]: loss_d : 1.371, loss_g : 0.528
# [220/3000]: loss_d : 1.360, loss_g : 0.577
# [230/3000]: loss_d : 1.360, loss_g : 0.573
# [240/3000]: loss_d : 1.357, loss_g : 0.591
# [250/3000]: loss_d : 1.352, loss_g : 0.595
# [260/3000]: loss_d : 1.351, loss_g : 0.629
# [270/3000]: loss_d : 1.346, loss_g : 0.628
# [280/3000]: loss_d : 1.346, loss_g : 0.628
# [290/3000]: loss_d : 1.346, loss_g : 0.638
# [300/3000]: loss_d : 1.348, loss_g : 0.650
# [310/3000]: loss_d : 1.349, loss_g : 0.670
